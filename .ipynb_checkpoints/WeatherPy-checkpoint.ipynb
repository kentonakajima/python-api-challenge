# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\kento\anaconda3\lib\site-packages (0.0.6)
# Requirement already satisfied: kdtree>=0.12 in c:\users\kento\anaconda3\lib\site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 589

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
url = f"https://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"
print(url + "&q=seattle")
# Out:
# https://api.openweathermap.org/data/2.5/weather?units=metric&appid=a562407e90023794537b425c73b6e8c7&q=seattle

# %%
# Set the API base URL
url = f"https://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1
#     print(city_url)

    # Run an API request for each of the cities
    
    
    
    
    
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | volodarskiy
# Processing Record 3 of Set 1 | tagta
# Processing Record 4 of Set 1 | port-aux-francais
# Processing Record 5 of Set 1 | yellowknife
# Processing Record 6 of Set 1 | blackmans bay
# Processing Record 7 of Set 1 | edinburgh of the seven seas
# Processing Record 8 of Set 1 | grytviken
# Processing Record 9 of Set 1 | atafu village
# Processing Record 10 of Set 1 | invercargill
# Processing Record 11 of Set 1 | hamilton
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | st. john's
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | cabo san lucas
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | mammoth lakes
# Processing Record 18 of Set 1 | port elizabeth
# Processing Record 19 of Set 1 | puerto natales
# Processing Record 20 of Set 1 | bilibino
# Processing Record 21 of Set 1 | bethel
# Processing Record 22 of Set 1 | adamstown
# Processing Record 23 of Set 1 | shahrud
# Processing Record 24 of Set 1 | obubra
# Processing Record 25 of Set 1 | la'ie
# Processing Record 26 of Set 1 | stanley
# Processing Record 27 of Set 1 | lihue
# Processing Record 28 of Set 1 | kingscliff
# Processing Record 29 of Set 1 | crane
# Processing Record 30 of Set 1 | enewetak
# Processing Record 31 of Set 1 | polyarnyy
# Processing Record 32 of Set 1 | kolonia town
# Processing Record 33 of Set 1 | college
# Processing Record 34 of Set 1 | ilulissat
# Processing Record 35 of Set 1 | villa gesell
# Processing Record 36 of Set 1 | kingston
# Processing Record 37 of Set 1 | marquette
# Processing Record 38 of Set 1 | ponta delgada
# Processing Record 39 of Set 1 | constantia
# Processing Record 40 of Set 1 | troy
# Processing Record 41 of Set 1 | kavieng
# Processing Record 42 of Set 1 | waitangi
# Processing Record 43 of Set 1 | al bardiyah
# Processing Record 44 of Set 1 | nar'yan-mar
# Processing Record 45 of Set 1 | zhaqsy
# Processing Record 46 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 47 of Set 1 | longyearbyen
# Processing Record 48 of Set 1 | qingquan
# Processing Record 49 of Set 1 | taro
# Processing Record 50 of Set 1 | kapa'a
# Processing Record 0 of Set 2 | vorgashor
# Processing Record 1 of Set 2 | olonkinbyen
# Processing Record 2 of Set 2 | sitka
# Processing Record 3 of Set 2 | talnakh
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | margate
# Processing Record 6 of Set 2 | sandnessjoen
# Processing Record 7 of Set 2 | miles city
# Processing Record 8 of Set 2 | badger
# Processing Record 9 of Set 2 | anuradhapura
# Processing Record 10 of Set 2 | ulan bator
# Processing Record 11 of Set 2 | avarua
# Processing Record 12 of Set 2 | port mathurin
# Processing Record 13 of Set 2 | fort bragg
# Processing Record 14 of Set 2 | iskateley
# Processing Record 15 of Set 2 | bucyrus
# Processing Record 16 of Set 2 | gadzhiyevo
# Processing Record 17 of Set 2 | minas de marcona
# Processing Record 18 of Set 2 | lompoc
# Processing Record 19 of Set 2 | iqaluit
# Processing Record 20 of Set 2 | arraial do cabo
# Processing Record 21 of Set 2 | tiksi
# Processing Record 22 of Set 2 | happy valley-goose bay
# Processing Record 23 of Set 2 | bel ombre
# Processing Record 24 of Set 2 | linton military camp
# City not found. Skipping...
# Processing Record 25 of Set 2 | mil'kovo
# Processing Record 26 of Set 2 | palmer
# Processing Record 27 of Set 2 | jacmel
# Processing Record 28 of Set 2 | haimen
# Processing Record 29 of Set 2 | amga
# Processing Record 30 of Set 2 | motueka
# Processing Record 31 of Set 2 | celestun
# Processing Record 32 of Set 2 | papatowai
# Processing Record 33 of Set 2 | la sarre
# Processing Record 34 of Set 2 | isafjordur
# Processing Record 35 of Set 2 | wailua homesteads
# Processing Record 36 of Set 2 | onguday
# Processing Record 37 of Set 2 | port lincoln
# Processing Record 12 of Set 4 | fortuna
# Processing Record 13 of Set 4 | maragogi
# Processing Record 14 of Set 4 | christchurch
# Processing Record 15 of Set 4 | argo
# Processing Record 16 of Set 4 | greenville
# Processing Record 17 of Set 4 | kangding
# Processing Record 18 of Set 4 | sinabang
# Processing Record 19 of Set 4 | fale old settlement
# Processing Record 20 of Set 4 | kayangel
# Processing Record 21 of Set 4 | falkenberg
# Processing Record 22 of Set 4 | east london
# Processing Record 23 of Set 4 | diu
# Processing Record 24 of Set 4 | thompson
# Processing Record 25 of Set 4 | zhanibek
# Processing Record 26 of Set 4 | smithers
# Processing Record 27 of Set 4 | lata
# Processing Record 28 of Set 4 | russkaya polyana
# Processing Record 29 of Set 4 | ulsteinvik
# Processing Record 30 of Set 4 | port alfred
# Processing Record 31 of Set 4 | kone
# Processing Record 32 of Set 4 | tralee
# Processing Record 33 of Set 4 | simanggang
# Processing Record 34 of Set 4 | mont-dore
# Processing Record 35 of Set 4 | belomorsk
# Processing Record 36 of Set 4 | afaahiti
# Processing Record 37 of Set 4 | fisterra
# Processing Record 38 of Set 4 | norton shores
# Processing Record 39 of Set 4 | vilyuchinsk
# Processing Record 40 of Set 4 | hailar
# Processing Record 41 of Set 4 | albacete
# Processing Record 42 of Set 4 | nadi
# Processing Record 43 of Set 4 | arkhangel'sk
# Processing Record 44 of Set 4 | gamba
# Processing Record 45 of Set 4 | xilin hot
# Processing Record 46 of Set 4 | pandan
# Processing Record 47 of Set 4 | port blair
# Processing Record 48 of Set 4 | al qanatir al khayriyah
# Processing Record 49 of Set 4 | luanda
# Processing Record 0 of Set 5 | boali
# Processing Record 1 of Set 5 | loudun
# Processing Record 2 of Set 5 | tucuma
# Processing Record 3 of Set 5 | al 'aziziyah
# Processing Record 4 of Set 5 | mount pearl
# Processing Record 5 of Set 5 | chu
# Processing Record 6 of Set 5 | muroto-misakicho
# Processing Record 7 of Set 5 | vilyuysk
# Processing Record 8 of Set 5 | klyuchi
# Processing Record 9 of Set 5 | boende
# Processing Record 10 of Set 5 | nadym
# Processing Record 11 of Set 5 | shakawe
# Processing Record 12 of Set 5 | carbonear
# Processing Record 13 of Set 5 | haenam
# Processing Record 14 of Set 5 | daru
# Processing Record 15 of Set 5 | kijang
# Processing Record 16 of Set 5 | new norfolk
# Processing Record 17 of Set 5 | lepsy
# Processing Record 18 of Set 5 | pangody
# Processing Record 19 of Set 5 | spring creek
# Processing Record 20 of Set 5 | el ejido
# Processing Record 21 of Set 5 | kaspiyskiy
# Processing Record 22 of Set 5 | beyneu
# Processing Record 23 of Set 5 | pasni
# Processing Record 24 of Set 5 | vila velha
# Processing Record 25 of Set 5 | nagqu
# Processing Record 26 of Set 5 | cururupu
# Processing Record 27 of Set 5 | dwarka
# Processing Record 28 of Set 5 | kodiak
# Processing Record 29 of Set 5 | khadyzhensk
# Processing Record 30 of Set 5 | sandpoint
# Processing Record 31 of Set 5 | pontianak
# Processing Record 32 of Set 5 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 33 of Set 5 | howard springs
# Processing Record 34 of Set 5 | yermentau
# Processing Record 35 of Set 5 | as sulayyil
# Processing Record 36 of Set 5 | alenquer
# Processing Record 37 of Set 5 | niamey
# Processing Record 38 of Set 5 | ancud
# Processing Record 39 of Set 5 | ruma
# Processing Record 40 of Set 5 | mountain home
# Processing Record 41 of Set 5 | tranovaho
# City not found. Skipping...
# Processing Record 42 of Set 5 | el calafate
# Processing Record 43 of Set 5 | mabaruma
# Processing Record 44 of Set 5 | bodo
# Processing Record 45 of Set 5 | faya-largeau
# Processing Record 46 of Set 5 | avanigadda
# Processing Record 47 of Set 5 | xinmin
# Processing Record 48 of Set 5 | vila franca do campo
# Processing Record 49 of Set 5 | tazacorte
# Processing Record 0 of Set 6 | weatherford
# Processing Record 1 of Set 6 | hasaki
# Processing Record 2 of Set 6 | luderitz
# Processing Record 3 of Set 6 | kavaratti
# Processing Record 4 of Set 6 | fortuna foothills
# Processing Record 5 of Set 6 | jamestown
# Processing Record 6 of Set 6 | yagry
# City not found. Skipping...
# Processing Record 7 of Set 6 | urrugne
# Processing Record 8 of Set 6 | beebe
# Processing Record 9 of Set 6 | utrik
# Processing Record 10 of Set 6 | juan griego
# Processing Record 11 of Set 6 | alice town
# Processing Record 12 of Set 6 | al shamkhah city
# City not found. Skipping...
# Processing Record 13 of Set 6 | makushino
# Processing Record 14 of Set 6 | hermanus
# Processing Record 15 of Set 6 | zemio
# Processing Record 16 of Set 6 | newman
# Processing Record 17 of Set 6 | portland
# Processing Record 18 of Set 6 | sretensk
# Processing Record 19 of Set 6 | praia
# Processing Record 20 of Set 6 | santa vitoria do palmar
# Processing Record 21 of Set 6 | nabire
# Processing Record 22 of Set 6 | januaria
# Processing Record 23 of Set 6 | chibougamau
# Processing Record 24 of Set 6 | lagos
# Processing Record 25 of Set 6 | mana
# Processing Record 26 of Set 6 | ceeldheer
# Processing Record 27 of Set 6 | oberstdorf
# Processing Record 28 of Set 6 | birzai
# Processing Record 29 of Set 6 | mushie
# Processing Record 30 of Set 6 | greymouth
# Processing Record 31 of Set 6 | zalingei
# Processing Record 32 of Set 6 | anadyr
# Processing Record 33 of Set 6 | touros
# Processing Record 34 of Set 6 | tsiombe
# Processing Record 35 of Set 6 | borkum
# Processing Record 36 of Set 6 | talcahuano
# Processing Record 37 of Set 6 | redencao
# Processing Record 38 of Set 6 | geraldton
# Processing Record 39 of Set 6 | ko pha ngan
# Processing Record 40 of Set 6 | yanchep
# Processing Record 41 of Set 6 | vodnyy
# Processing Record 42 of Set 6 | kailua-kona
# Processing Record 43 of Set 6 | shihezi
# Processing Record 44 of Set 6 | alupka
# Processing Record 45 of Set 6 | tolanaro
# Processing Record 46 of Set 6 | kupang
# Processing Record 47 of Set 6 | san jacinto
# Processing Record 48 of Set 6 | carutapera
# Processing Record 49 of Set 6 | najafabad
# Processing Record 0 of Set 7 | erenhot
# Processing Record 1 of Set 7 | kaa-khem
# Processing Record 2 of Set 7 | mejit
# Processing Record 3 of Set 7 | holualoa
# Processing Record 4 of Set 7 | weno
# Processing Record 5 of Set 7 | laguna
# Processing Record 6 of Set 7 | saratamata
# City not found. Skipping...
# Processing Record 7 of Set 7 | malvan
# Processing Record 8 of Set 7 | okha
# Processing Record 9 of Set 7 | suoyarvi
# Processing Record 10 of Set 7 | bairnsdale
# Processing Record 11 of Set 7 | sidi bel abbes
# Processing Record 12 of Set 7 | woolgoolga
# Processing Record 13 of Set 7 | dawesville
# Processing Record 14 of Set 7 | mount isa
# Processing Record 15 of Set 7 | abilene
# Processing Record 16 of Set 7 | carnarvon
# Processing Record 41 of Set 8 | alice springs
# Processing Record 42 of Set 8 | manvi
# Processing Record 43 of Set 8 | yelovo
# Processing Record 44 of Set 8 | champagnole
# Processing Record 45 of Set 8 | deqen
# Processing Record 46 of Set 8 | colonia
# Processing Record 47 of Set 8 | rabaul
# Processing Record 48 of Set 8 | coronel dorrego
# Processing Record 49 of Set 8 | hola
# Processing Record 0 of Set 9 | healesville
# Processing Record 1 of Set 9 | port douglas
# Processing Record 2 of Set 9 | laporte
# Processing Record 3 of Set 9 | arno
# Processing Record 4 of Set 9 | duck lake
# Processing Record 5 of Set 9 | tomigusuku
# Processing Record 6 of Set 9 | mingshui
# Processing Record 7 of Set 9 | harnoli
# Processing Record 8 of Set 9 | hailin
# Processing Record 9 of Set 9 | ciudad altamirano
# Processing Record 10 of Set 9 | nurota
# Processing Record 11 of Set 9 | aver-o-mar
# Processing Record 12 of Set 9 | ilebo
# Processing Record 13 of Set 9 | bardai
# Processing Record 14 of Set 9 | masuguru
# Processing Record 15 of Set 9 | jayapura
# Processing Record 16 of Set 9 | sampit
# Processing Record 17 of Set 9 | prado
# Processing Record 18 of Set 9 | shalqar
# Processing Record 19 of Set 9 | camana
# Processing Record 20 of Set 9 | qarqaraly
# Processing Record 21 of Set 9 | kawthoung
# City not found. Skipping...
# Processing Record 22 of Set 9 | naze
# Processing Record 23 of Set 9 | tazovsky
# Processing Record 24 of Set 9 | gowurdak
# Processing Record 25 of Set 9 | vera
# Processing Record 26 of Set 9 | gunjur
# Processing Record 27 of Set 9 | katav-ivanovsk
# Processing Record 28 of Set 9 | zheleznogorsk-ilimskiy
# Processing Record 29 of Set 9 | nalut
# Processing Record 30 of Set 9 | kuruman
# Processing Record 31 of Set 9 | turaif
# Processing Record 32 of Set 9 | slawharad
# Processing Record 33 of Set 9 | antofagasta
# Processing Record 34 of Set 9 | san antonio de pale
# Processing Record 35 of Set 9 | kruisfontein
# Processing Record 36 of Set 9 | lodwar
# Processing Record 37 of Set 9 | usogorsk
# Processing Record 38 of Set 9 | itoman
# Processing Record 39 of Set 9 | hiratacho
# Processing Record 40 of Set 9 | selfoss
# Processing Record 41 of Set 9 | spanish wells
# Processing Record 42 of Set 9 | am timan
# Processing Record 43 of Set 9 | salahonda
# Processing Record 44 of Set 9 | bonthe
# Processing Record 45 of Set 9 | ghorawal
# Processing Record 46 of Set 9 | umm kaddadah
# Processing Record 47 of Set 9 | pont-l'abbe
# City not found. Skipping...
# Processing Record 48 of Set 9 | brokopondo
# Processing Record 49 of Set 9 | neiafu
# Processing Record 0 of Set 10 | kataragama
# City not found. Skipping...
# Processing Record 1 of Set 10 | karratha
# Processing Record 2 of Set 10 | devon
# Processing Record 3 of Set 10 | dudinka
# Processing Record 4 of Set 10 | santo antonio
# Processing Record 5 of Set 10 | hotan
# Processing Record 6 of Set 10 | hong kong
# Processing Record 7 of Set 10 | raja
# Processing Record 8 of Set 10 | buinsk
# Processing Record 9 of Set 10 | pisco
# Processing Record 10 of Set 10 | lat yao
# Processing Record 11 of Set 10 | okhotsk
# Processing Record 12 of Set 10 | saguenay
# Processing Record 13 of Set 10 | richards bay
# Processing Record 14 of Set 10 | chonchi
# Processing Record 15 of Set 10 | sitia
# Processing Record 16 of Set 10 | howrah
# Processing Record 17 of Set 10 | pacific grove
# Processing Record 18 of Set 10 | hammerfest
# Processing Record 19 of Set 10 | oriximina
# Processing Record 20 of Set 10 | ad dabbah
# Processing Record 21 of Set 10 | okakarara
# Processing Record 22 of Set 10 | chengdu
# Processing Record 23 of Set 10 | swift current
# Processing Record 24 of Set 10 | wanning
# Processing Record 25 of Set 10 | kununurra
# Processing Record 26 of Set 10 | wa
# City not found. Skipping...
# Processing Record 27 of Set 10 | savanna-la-mar
# Processing Record 28 of Set 10 | port saint john's
# Processing Record 29 of Set 10 | berrotaran
# Processing Record 30 of Set 10 | north ward
# Processing Record 31 of Set 10 | tavda
# Processing Record 32 of Set 10 | port pirie
# Processing Record 33 of Set 10 | paita
# Processing Record 34 of Set 10 | seogwipo
# City not found. Skipping...
# Processing Record 35 of Set 10 | casa santa
# City not found. Skipping...
# Processing Record 36 of Set 10 | sangmelima
# Processing Record 37 of Set 10 | sonsorol village
# City not found. Skipping...
# Processing Record 38 of Set 10 | bikenibeu village
# Processing Record 39 of Set 10 | raduzhny
# Processing Record 40 of Set 10 | ha'il
# Processing Record 41 of Set 10 | yen bai
# Processing Record 42 of Set 10 | charters towers
# Processing Record 43 of Set 10 | atherton
# Processing Record 44 of Set 10 | hayma'
# City not found. Skipping...
# Processing Record 45 of Set 10 | tura
# Processing Record 46 of Set 10 | mahabe
# City not found. Skipping...
# Processing Record 47 of Set 10 | altai
# Processing Record 48 of Set 10 | santiago del torno
# Processing Record 49 of Set 10 | ugoofaaru
# Processing Record 0 of Set 11 | bilaspur
# Processing Record 1 of Set 11 | tangalle
# Processing Record 2 of Set 11 | gokwe
# Processing Record 3 of Set 11 | martapura
# Processing Record 4 of Set 11 | northam
# Processing Record 5 of Set 11 | sao vicente
# Processing Record 6 of Set 11 | carlow
# Processing Record 7 of Set 11 | nieuw amsterdam
# Processing Record 8 of Set 11 | la rinconada
# Processing Record 9 of Set 11 | katsuren-haebaru
# Processing Record 10 of Set 11 | remire-montjoly
# Processing Record 11 of Set 11 | mandalgovi
# Processing Record 12 of Set 11 | kwang binh
# Processing Record 13 of Set 11 | sherwood park
# Processing Record 14 of Set 11 | san ignacio
# Processing Record 15 of Set 11 | vryburg
# Processing Record 16 of Set 11 | viedma
# Processing Record 17 of Set 11 | bialobrzegi
# Processing Record 18 of Set 11 | malakal
# Processing Record 19 of Set 11 | sidirokastro
# Processing Record 20 of Set 11 | ystad
# Processing Record 21 of Set 11 | koulikoro
# Processing Record 22 of Set 11 | beipiao
# Processing Record 23 of Set 11 | belyy yar
# Processing Record 24 of Set 11 | phang nga
# Processing Record 25 of Set 11 | knyaze-volkonskoye
# Processing Record 26 of Set 11 | coruripe
# Processing Record 27 of Set 11 | lerwick
# Processing Record 28 of Set 11 | general roca
# Processing Record 29 of Set 11 | toga village
# City not found. Skipping...
# Processing Record 30 of Set 11 | moose jaw
# Processing Record 31 of Set 11 | luwuk
# Processing Record 32 of Set 11 | qorveh
# Processing Record 33 of Set 11 | punta del este
# Processing Record 34 of Set 11 | saint-joseph
# Processing Record 35 of Set 11 | buka
# Processing Record 36 of Set 11 | tippi
# Processing Record 37 of Set 11 | bubaque
# Processing Record 38 of Set 11 | nenjiang
# Processing Record 39 of Set 11 | siwa oasis
# Processing Record 40 of Set 11 | mugia
# Processing Record 41 of Set 11 | outjo
# Processing Record 42 of Set 11 | fengrun
# Processing Record 43 of Set 11 | mweka
# Processing Record 44 of Set 11 | nicoya
# Processing Record 45 of Set 11 | ouadda
# Processing Record 46 of Set 11 | tuensang
# Processing Record 47 of Set 11 | khash
# Processing Record 48 of Set 11 | dabat
# Processing Record 49 of Set 11 | coahuayana de hidalgo
# Processing Record 0 of Set 12 | westwood
# Processing Record 1 of Set 12 | coquimbo
# Processing Record 2 of Set 12 | ubari
# Processing Record 3 of Set 12 | tamanrasset
# Processing Record 4 of Set 12 | villa alberto andres alvarado aramburo
# City not found. Skipping...
# Processing Record 5 of Set 12 | monteiro
# Processing Record 6 of Set 12 | kotlas
# Processing Record 7 of Set 12 | kourou
# Processing Record 8 of Set 12 | weining
# Processing Record 9 of Set 12 | ouesso
# Processing Record 10 of Set 12 | andergrove
# Processing Record 11 of Set 12 | igrim
# Processing Record 12 of Set 12 | klaksvik
# Processing Record 13 of Set 12 | fuengirola
# Processing Record 14 of Set 12 | eirunepe
# Processing Record 15 of Set 12 | ixtapa
# Processing Record 16 of Set 12 | porto novo
# Processing Record 17 of Set 12 | cacoal
# Processing Record 18 of Set 12 | pacasmayo
# Processing Record 19 of Set 12 | hankasalmi
# Processing Record 20 of Set 12 | al ghayzah
# Processing Record 21 of Set 12 | grand-bassam
# Processing Record 22 of Set 12 | harstad
# Processing Record 23 of Set 12 | jianshui
# Processing Record 24 of Set 12 | maxixe
# Processing Record 25 of Set 12 | evanston
# Processing Record 26 of Set 12 | santa maria da vitoria
# Processing Record 27 of Set 12 | kodinsk
# Processing Record 28 of Set 12 | shimoda
# Processing Record 29 of Set 12 | akureyri
# Processing Record 30 of Set 12 | rio grande
# Processing Record 31 of Set 12 | wellington
# Processing Record 32 of Set 12 | paracatu
# Processing Record 33 of Set 12 | reftinskiy
# Processing Record 34 of Set 12 | tual
# Processing Record 35 of Set 12 | dunedin
# Processing Record 36 of Set 12 | beichengqu
# Processing Record 37 of Set 12 | kuta
# Processing Record 38 of Set 12 | kargat
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          560
# Lat           560
# Lng           560
# Max Temp      560
# Humidity      560
# Cloudiness    560
# Wind Speed    560
# Country       560
# Date          560
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         bredasdorp -34.5322   20.0403     10.60        79          18
# 1        volodarskiy  46.4013   48.5409     14.99        74         100
# 2              tagta  41.6504   59.9164     21.97        40           0
# 3  port-aux-francais -49.3500   70.2167      5.48        97         100
# 4        yellowknife  62.4560 -114.3525     13.01        90         100
#
#    Wind Speed Country        Date
# 0        3.16      ZA  1694969351
# 1        1.26      RU  1694969351
# 2        3.09      TM  1694969351
# 3       13.11      TF  1694969352
# 4        5.66      CA  1694969352

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               bredasdorp -34.5322   20.0403     10.60        79          18
# 1              volodarskiy  46.4013   48.5409     14.99        74         100
# 2                    tagta  41.6504   59.9164     21.97        40           0
# 3        port-aux-francais -49.3500   70.2167      5.48        97         100
# 4              yellowknife  62.4560 -114.3525     13.01        90         100
#
#          Wind Speed Country        Date
# City_ID
# 0              3.16      ZA  1694969351
# 1              1.26      RU  1694969351
# 2              3.09      TM  1694969351
# 3             13.11      TF  1694969352
# 4              5.66      CA  1694969352

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o")
plt.ylabel("Max Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)


# Incorporate the other graph properties
plt.title("World City Max Temprature vs. Latitude")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)


# Incorporate the other graph properties
plt.title("World City Humidity vs. Latitude")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)


# Incorporate the other graph properties
plt.title("World City Cloudiness vs. Latitude")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o")
plt.ylabel("Wind Speed (kmh)")
plt.xlabel("Latitude")
plt.grid(True)
# Incorporate the other graph properties
plt.title("World City Wind Speed vs. Latitude")


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE
def plot_liner_regression(x_value, y_value, title, text_coord):
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
    regress_value = x_value * slope + intercept
    line_eq = f"y = {round(slope,2)}x 9 {round(intercept,2)}"
    
    plt.scatter(x_value, y_value)
    plt.plot(x_value, regress_value, "r-")
    plt.annotate(line_eq, text_coord, fontsize=15, color="red")
    plt.xlabel("Lat")
    plt.ylabel(title)
    print(f"The r-value is {rvalue ** 2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df = city_data_df[city_data_df["Lat"] >=0]
# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        volodarskiy  46.4013   48.5409     14.99        74         100
# 2              tagta  41.6504   59.9164     21.97        40           0
# 4        yellowknife  62.4560 -114.3525     13.01        90         100
# 10          hamilton  39.1834  -84.5333     24.58        61         100
# 11            albany  42.6001  -73.9662     22.32        60          92
#
#          Wind Speed Country        Date
# City_ID
# 1              1.26      RU  1694969351
# 2              3.09      TM  1694969351
# 4              5.66      CA  1694969352
# 10             2.06      US  1694969330
# 11             0.45      US  1694969352

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                         bredasdorp -34.5322   20.0403     10.60        79
# 3                  port-aux-francais -49.3500   70.2167      5.48        97
# 5                      blackmans bay -43.0167  147.3167      8.07        72
# 6        edinburgh of the seven seas -37.0676  -12.3116     12.76        83
# 7                          grytviken -54.2811  -36.5092     -0.46        86
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                18        3.16      ZA  1694969351
# 3               100       13.11      TF  1694969352
# 5                54        3.33      AU  1694969353
# 6                63        8.36      SH  1694969353
# 7                92        7.49      GS  1694969353

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_liner_regression(x_values, y_values, "Max Temp", (6, -10))
# Out:
# The r-value is 0.598189652832502

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_liner_regression(x_values, y_values, "Max Temp", (-55, 5))
# Out:
# The r-value is 0.6091362703740559

# %% [markdown]
# **Discussion about the linear relationship:** In northern hemisphere, temprature and latitude is inversely proportional as temprature decreases when latitude increases.  In southern hemisphere, temprature and latitude is directly proportional as temprature increases when latitude increases.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_liner_regression(x_values, y_values, "Humidity", (50, -20))
# Out:
# The r-value is 0.00042338824352511416

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_liner_regression(x_values, y_values, "Humidity", (-50, 30))
# Out:
# The r-value is 0.000604303491334681

# %% [markdown]
# **Discussion about the linear relationship:** There is no material correlation between humidity and latitude in both northern and souther hemipheres as regression lines are either flat or close to flat.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_liner_regression(x_values, y_values, "Cloudiness", (40, 20))
# Out:
# The r-value is 4.8573917284384616e-05

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_liner_regression(x_values, y_values, "Cloudiness", (-50, 20))
# Out:
# The r-value is 0.010109353428653213

# %% [markdown]
# **Discussion about the linear relationship:** There is no material correlation between cloudiness and latitude in both northern and souther hemipheres as regression lines are either flat or close to flat.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_liner_regression(x_values, y_values, "Wind Speed", (10, 15))
# Out:
# The r-value is 0.0011479721172878731

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_liner_regression(x_values, y_values, "Wind Speed", (-50, 10))
# Out:
# The r-value is 0.023659451542007964

# %% [markdown]
# **Discussion about the linear relationship:** There is no material correlation between wind speed and latitude in both northern and souther hemipheres as regression lines are either flat or close to flat.
